# %%
# !python --version
# Out:
# Python 3.11.13

# %% [markdown]
# # 1. Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

# Load dataset dari Google Drive
file_path = '/content/drive/MyDrive/Colab Notebooks/AIS Dataset on Cloud DDoS Attacks.csv'
df = pd.read_csv(file_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 2. EDA (Exploratory Data Analysis)

# %%
# Cek dimensi dataset
print("Dimensi dataset:", df.shape)
# Out:
# Dimensi dataset: (52318, 80)

# %%
# Tampilkan 5 baris pertama
df.head()
# Out:
#     Source Port   Destination Port   Protocol   Flow Duration  \
# 0         52380                443          6               1
# 1           443              52380          6               2
# 2           443              52380          6             218
# 3             0                  0          0       115366430
# 4            68                 67         17       109157387
#
#     Total Fwd Packets   Total Backward Packets  Total Length of Fwd Packets  \
# 0                   2                        0                            0
# 1                   3                        0                           62
# 2                   1                        2                            0
# 3                  52                        0                            0
# 4                  16                        0                         4800
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       0
# 1                             0                      31
# 2                             0                       0
# 3                             0                       0
# 4                             0                     300
#
#     Fwd Packet Length Min  ...   Active Mean    Active Std   Active Max  \
# 0                       0  ...  0.000000e+00  0.000000e+00            0
# 1                       0  ...  0.000000e+00  0.000000e+00            0
# 2                       0  ...  0.000000e+00  0.000000e+00            0
# 3                       0  ...  6.666667e+00  1.073087e+00            8
# 4                     300  ...  5.929966e+06  3.774939e+06     10054849
#
#     Active Min     Idle Mean      Idle Std   Idle Max   Idle Min   Inbound  \
# 0            0  0.000000e+00  0.000000e+00          0          0         0
# 1            0  0.000000e+00  0.000000e+00          0          0         1
# 2            0  0.000000e+00  0.000000e+00          0          0         1
# 3            4  9.613862e+06  2.884856e+05    9988327    9110910         0
# 4      2647210  1.015194e+07  2.795046e+06   14600796    6304546         0
#
#     label
# 0  BENIGN
# 1  BENIGN
# 2  BENIGN
# 3  BENIGN
# 4  BENIGN
#
# [5 rows x 80 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cek nilai unik label
print("Distribusi label:")
print(df['label'].value_counts())

# Visualisasi distribusi label
sns.countplot(data=df, x='label')
plt.title("Distribusi Label BENIGN vs DDOS")
plt.xlabel("Label")
plt.ylabel("Jumlah")
plt.xticks(rotation=0)
plt.show()
# Out:
# Distribusi label:
# label
# DDOS      26892
# BENIGN    25426
# Name: count, dtype: int64

# %%
# Hitung korelasi antar fitur
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), cmap='coolwarm', annot=False, linewidths=0.5)
plt.title("Heatmap Korelasi Antar Fitur")
plt.show()

# %% [markdown]
# # 3. Pre-processing Data

# %%
# Cek nilai unik label
print("Nilai unik pada kolom 'label':", df['label'].unique())

# Encode label: BENIGN = 0, DDOS = 1
df['label'] = df['label'].map({'BENIGN': 0, 'DDOS': 1})

# Pastikan tidak ada nilai NaN setelah encoding
print("Cek nilai NaN setelah encoding:", df['label'].isnull().sum())

# Pisahkan fitur dan label
X = df.drop(columns=['label'])  # Semua kolom kecuali label
y = df['label']

# Normalisasi fitur
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Ubah kembali ke DataFrame untuk memudahkan analisis ke depan
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

print("Normalisasi selesai. Bentuk data setelah normalisasi:", X_scaled_df.shape)
# Out:
# Nilai unik pada kolom 'label': ['BENIGN' 'DDOS']
# Cek nilai NaN setelah encoding: 0
# Normalisasi selesai. Bentuk data setelah normalisasi: (52318, 79)

# %% [markdown]
# # Train Baseline SVM + Evaluasi

# %%
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score
import numpy as np

# Inisialisasi model SVM (kernel RBF)
svm = SVC(kernel='rbf', random_state=42)

# K-Fold Cross Validation
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Simpan hasil evaluasi
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []
kappa_scores = []

for fold, (train_index, test_index) in enumerate(skf.split(X_scaled_df, y), 1):
    X_train, X_test = X_scaled_df.iloc[train_index], X_scaled_df.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Training SVM
    svm.fit(X_train, y_train)
    y_pred = svm.predict(X_test)

    # Evaluasi metrik
    accuracy_scores.append(accuracy_score(y_test, y_pred))
    precision_scores.append(precision_score(y_test, y_pred))
    recall_scores.append(recall_score(y_test, y_pred))
    f1_scores.append(f1_score(y_test, y_pred))
    kappa_scores.append(cohen_kappa_score(y_test, y_pred))

    print(f"Fold {fold} selesai")

# Tampilkan rata-rata hasil
print("\n=== Baseline SVM Evaluation (10-Fold CV) ===")
print(f"Accuracy: {np.mean(accuracy_scores):.4f}")
print(f"Precision: {np.mean(precision_scores):.4f}")
print(f"Recall: {np.mean(recall_scores):.4f}")
print(f"F1-Score: {np.mean(f1_scores):.4f}")
print(f"Kappa: {np.mean(kappa_scores):.4f}")
# Out:
# Fold 1 selesai
# Fold 2 selesai
# Fold 3 selesai
# Fold 4 selesai
# Fold 5 selesai
# Fold 6 selesai
# Fold 7 selesai
# Fold 8 selesai
# Fold 9 selesai
# Fold 10 selesai
#
# === Baseline SVM Evaluation (10-Fold CV) ===
# Accuracy: 0.9980
# Precision: 0.9977
# Recall: 0.9984
# F1-Score: 0.9980
# Kappa: 0.9960

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Buat DataFrame dari skor-skor yang telah dihitung
df_baseline = pd.DataFrame({
    'Accuracy': accuracy_scores,
    'Precision': precision_scores,
    'Recall': recall_scores,
    'F1_Score': f1_scores,
    'Kappa': kappa_scores
})

# Ubah ke bentuk long untuk plotting (melt)
df_melted = df_baseline.melt(var_name='Metrik', value_name='Skor')

# Plot boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_melted, x='Metrik', y='Skor', palette='Set3')

# Tambahkan judul dan label
plt.title('Distribusi Metrik Evaluasi - Baseline SVM (10-Fold CV)', fontsize=14)
plt.ylabel('Nilai')
plt.xlabel('Metrik')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-5-3067649493.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_melted, x='Metrik', y='Skor', palette='Set3')

# %% [markdown]
# Simpan Hasil Evaluasi Baseline SVM ke CSV

# %%
import pandas as pd

# Buat DataFrame dari hasil evaluasi SVM
baseline_results = pd.DataFrame({
    'Fold': list(range(1, 11)),
    'Accuracy': accuracy_scores,
    'Precision': precision_scores,
    'Recall': recall_scores,
    'F1_Score': f1_scores,
    'Kappa': kappa_scores
})

# Simpan ke Google Drive
output_path = '/content/drive/MyDrive/Colab Notebooks/baseline_svm_results.csv'
baseline_results.to_csv(output_path, index=False)

print(f"Hasil evaluasi baseline SVM berhasil disimpan ke: {output_path}")
# Out:
# Hasil evaluasi baseline SVM berhasil disimpan ke: /content/drive/MyDrive/Colab Notebooks/baseline_svm_results.csv

# %% [markdown]
# # Seleksi Fitur SVM

# %% [markdown]
# # a. Correlation-based Feature Selection (CFS Approximation)

# %%
# Gabungkan kembali X dan y untuk analisis korelasi
df_corr = X_scaled_df.copy()
df_corr['label'] = y

# Hitung korelasi Pearson antara fitur dan label
correlations = df_corr.corr()['label'].drop('label')

# Tampilkan korelasi fitur (dari tinggi ke rendah)
print("Korelasi fitur terhadap label:")
print(correlations.sort_values(ascending=False))

# Threshold korelasi (misal 0.1)
threshold = 0.1
selected_features_cfs = correlations[abs(correlations) > threshold].index.tolist()

# Informasi hasil seleksi
print(f"\nJumlah fitur terpilih (|corr| > {threshold}): {len(selected_features_cfs)}")
print("Fitur terpilih:")
print(selected_features_cfs)

# Buat DataFrame fitur terpilih
X_cfs = X_scaled_df[selected_features_cfs]
# Out:
# Korelasi fitur terhadap label:
#  Inbound                   0.828626
#  Min Packet Length         0.610927
#  Fwd Packet Length Min     0.609752
#  Avg Fwd Segment Size      0.602293
#  Fwd Packet Length Mean    0.602293
#                              ...
#  Fwd Avg Packets/Bulk           NaN
#  Fwd Avg Bulk Rate              NaN
#  Bwd Avg Bytes/Bulk             NaN
#  Bwd Avg Packets/Bulk           NaN
# Bwd Avg Bulk Rate               NaN
# Name: label, Length: 79, dtype: float64
#
# Jumlah fitur terpilih (|corr| > 0.1): 48
# Fitur terpilih:
# [' Source Port', ' Destination Port', ' Protocol', ' Flow Duration', ' Total Backward Packets', 'Total Length of Fwd Packets', ' Fwd Packet Length Max', ' Fwd Packet Length Min', ' Fwd Packet Length Mean', ' Fwd Packet Length Std', 'Bwd Packet Length Max', ' Bwd Packet Length Min', ' Bwd Packet Length Mean', ' Bwd Packet Length Std', ' Flow IAT Std', ' Flow IAT Max', 'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std', ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', 'Fwd Packets/s', ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean', ' Packet Length Std', ' RST Flag Count', ' URG Flag Count', ' CWE Flag Count', ' Down/Up Ratio', ' Average Packet Size', ' Avg Fwd Segment Size', ' Avg Bwd Segment Size', ' Subflow Fwd Bytes', ' Subflow Bwd Packets', 'Init_Win_bytes_forward', ' Init_Win_bytes_backward', ' act_data_pkt_fwd', ' min_seg_size_forward', 'Idle Mean', ' Idle Max', ' Idle Min', ' Inbound']

# %%
from sklearn.svm import SVC

# Inisialisasi ulang model SVM dengan kernel RBF
svm_cfs = SVC(kernel='rbf', random_state=42)

# Reset metrik
acc_cfs, prec_cfs, rec_cfs, f1_cfs, kappa_cfs = [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(skf.split(X_cfs, y), 1):
    X_train, X_test = X_cfs.iloc[train_idx], X_cfs.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    svm_cfs.fit(X_train, y_train)
    y_pred = svm_cfs.predict(X_test)

    acc_cfs.append(accuracy_score(y_test, y_pred))
    prec_cfs.append(precision_score(y_test, y_pred))
    rec_cfs.append(recall_score(y_test, y_pred))
    f1_cfs.append(f1_score(y_test, y_pred))
    kappa_cfs.append(cohen_kappa_score(y_test, y_pred))

    print(f"Fold {fold} selesai (SVM + CFS)")

# Rata-rata hasil
print("\n=== SVM + CFS Evaluation (10-Fold CV) ===")
print(f"Accuracy: {np.mean(acc_cfs):.4f}")
print(f"Precision: {np.mean(prec_cfs):.4f}")
print(f"Recall: {np.mean(rec_cfs):.4f}")
print(f"F1-Score: {np.mean(f1_cfs):.4f}")
print(f"Kappa: {np.mean(kappa_cfs):.4f}")
# Out:
# Fold 1 selesai (SVM + CFS)
# Fold 2 selesai (SVM + CFS)
# Fold 3 selesai (SVM + CFS)
# Fold 4 selesai (SVM + CFS)
# Fold 5 selesai (SVM + CFS)
# Fold 6 selesai (SVM + CFS)
# Fold 7 selesai (SVM + CFS)
# Fold 8 selesai (SVM + CFS)
# Fold 9 selesai (SVM + CFS)
# Fold 10 selesai (SVM + CFS)
#
# === SVM + CFS Evaluation (10-Fold CV) ===
# Accuracy: 0.9982
# Precision: 0.9973
# Recall: 0.9991
# F1-Score: 0.9982
# Kappa: 0.9964

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Buat DataFrame dari hasil evaluasi
df_svm_cfs = pd.DataFrame({
    'Accuracy': acc_cfs,
    'Precision': prec_cfs,
    'Recall': rec_cfs,
    'F1_Score': f1_cfs,
    'Kappa': kappa_cfs
})

# Ubah ke format long (melt) agar bisa digunakan oleh seaborn
df_svm_cfs_melted = df_svm_cfs.melt(var_name='Metrik', value_name='Skor')

# Plot boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_svm_cfs_melted, x='Metrik', y='Skor', palette='Set2')

# Tambahkan judul dan label sumbu
plt.title('Distribusi Metrik Evaluasi - SVM (CFS)', fontsize=14)
plt.xlabel('Metrik')
plt.ylabel('Skor')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-8-283470301.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_svm_cfs_melted, x='Metrik', y='Skor', palette='Set2')

# %% [markdown]
# Simpan hasil evaluasi SVM + CFS ke CSV

# %%
svm_cfs_results = pd.DataFrame({
    'Fold': list(range(1, 11)),
    'Accuracy': acc_cfs,
    'Precision': prec_cfs,
    'Recall': rec_cfs,
    'F1_Score': f1_cfs,
    'Kappa': kappa_cfs
})

output_path_cfs = '/content/drive/MyDrive/Colab Notebooks/svm_cfs_results.csv'
svm_cfs_results.to_csv(output_path_cfs, index=False)

print(f"Hasil evaluasi SVM + CFS disimpan ke: {output_path_cfs}")
# Out:
# Hasil evaluasi SVM + CFS disimpan ke: /content/drive/MyDrive/Colab Notebooks/svm_cfs_results.csv

# %% [markdown]
# # b. Rough Set

# %%
from sklearn.feature_selection import mutual_info_classif
import pandas as pd

# Hitung mutual information setiap fitur terhadap label
mi_scores = mutual_info_classif(X_scaled_df, y, discrete_features=False)
mi_series = pd.Series(mi_scores, index=X_scaled_df.columns).sort_values(ascending=False)

# Pilih Top-N fitur
top_n = 20
selected_features_rs = mi_series.head(top_n).index.tolist()

# Tampilkan hasil seleksi fitur
print(f"Fitur terpilih dari Rough Set Simplified (Top {top_n} berdasarkan Mutual Information):")
print(selected_features_rs)

# Dataset akhir dengan fitur terpilih
X_rs = X_scaled_df[selected_features_rs]
# Out:
# Fitur terpilih dari Rough Set Simplified (Top 20 berdasarkan Mutual Information):
# [' Destination Port', ' Source Port', ' Fwd Packet Length Mean', ' Avg Fwd Segment Size', ' Max Packet Length', ' Average Packet Size', ' Packet Length Mean', ' Fwd Packet Length Max', ' Fwd Packet Length Min', ' Min Packet Length', 'Total Length of Fwd Packets', ' Subflow Fwd Bytes', ' Flow IAT Mean', ' Flow IAT Max', ' Inbound', 'Fwd Packets/s', ' Bwd Packets/s', ' Flow Duration', ' Flow IAT Std', ' Bwd Header Length']

# %%
from sklearn.svm import SVC

# Inisialisasi model SVM
svm_rs = SVC(kernel='rbf', random_state=42)

# Reset metrik
acc_rs, prec_rs, rec_rs, f1_rs, kappa_rs = [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(skf.split(X_rs, y), 1):
    X_train, X_test = X_rs.iloc[train_idx], X_rs.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    svm_rs.fit(X_train, y_train)
    y_pred = svm_rs.predict(X_test)

    acc_rs.append(accuracy_score(y_test, y_pred))
    prec_rs.append(precision_score(y_test, y_pred))
    rec_rs.append(recall_score(y_test, y_pred))
    f1_rs.append(f1_score(y_test, y_pred))
    kappa_rs.append(cohen_kappa_score(y_test, y_pred))

    print(f"Fold {fold} selesai")

# Rata-rata hasil
print("\n=== SVM + RS Evaluation (10-Fold CV) ===")
print(f"Accuracy: {np.mean(acc_rs):.4f}")
print(f"Precision: {np.mean(prec_rs):.4f}")
print(f"Recall: {np.mean(rec_rs):.4f}")
print(f"F1-Score: {np.mean(f1_rs):.4f}")
print(f"Kappa: {np.mean(kappa_rs):.4f}")
# Out:
# Fold 1 selesai
# Fold 2 selesai
# Fold 3 selesai
# Fold 4 selesai
# Fold 5 selesai
# Fold 6 selesai
# Fold 7 selesai
# Fold 8 selesai
# Fold 9 selesai
# Fold 10 selesai
#
# === SVM + RS Evaluation (10-Fold CV) ===
# Accuracy: 0.9979
# Precision: 0.9979
# Recall: 0.9981
# F1-Score: 0.9980
# Kappa: 0.9959

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Buat DataFrame dari hasil evaluasi
df_svm_rs = pd.DataFrame({
    'Accuracy': acc_rs,
    'Precision': prec_rs,
    'Recall': rec_rs,
    'F1_Score': f1_rs,
    'Kappa': kappa_rs
})

# Ubah ke format long (melt) agar bisa digunakan oleh seaborn
df_svm_rs_melted = df_svm_rs.melt(var_name='Metrik', value_name='Skor')

# Plot boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_svm_rs_melted, x='Metrik', y='Skor', palette='Set2')

# Tambahkan judul dan label sumbu
plt.title('Distribusi Metrik Evaluasi - SVM (RS)', fontsize=14)
plt.xlabel('Metrik')
plt.ylabel('Skor')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-11-2962318116.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_svm_rs_melted, x='Metrik', y='Skor', palette='Set2')

# %% [markdown]
# Simpan hasil evaluasi SVM + RS ke CSV

# %%
svm_rs_results = pd.DataFrame({
    'Fold': list(range(1, 11)),
    'Accuracy': acc_rs,
    'Precision': prec_rs,
    'Recall': rec_rs,
    'F1_Score': f1_rs,
    'Kappa': kappa_rs
})

output_path_rs = '/content/drive/MyDrive/Colab Notebooks/svm_rs_results.csv'
svm_rs_results.to_csv(output_path_rs, index=False)

print(f"Hasil evaluasi SVM + Rough Set disimpan ke: {output_path_rs}")
# Out:
# Hasil evaluasi SVM + Rough Set disimpan ke: /content/drive/MyDrive/Colab Notebooks/svm_rs_results.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load ketiga CSV
baseline = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SVM/baseline_svm_results.csv")
cfs = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SVM/svm_cfs_results.csv")
rs = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SVM/svm_rs_results.csv")

# Tambahkan kolom 'metode' sebagai label
baseline['metode'] = 'Baseline'
cfs['metode'] = 'CFS'
rs['metode'] = 'RS'

# Gabungkan semua menjadi satu DataFrame
df = pd.concat([baseline, cfs, rs], ignore_index=True)

# Ubah dari wide ke long format
df_long = pd.melt(df,
                  id_vars=['Fold', 'metode'],
                  value_vars=['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa'],
                  var_name='metrik',
                  value_name='nilai')

# Buat box plot
plt.figure(figsize=(12, 6))
sns.boxplot(x='metrik', y='nilai', hue='metode', data=df_long)
plt.title('Perbandingan Performa SVM (Baseline vs CFS vs RS)')
plt.ylabel('Nilai Metrik')
plt.xlabel('Metrik Evaluasi')
plt.legend(title='Metode')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
