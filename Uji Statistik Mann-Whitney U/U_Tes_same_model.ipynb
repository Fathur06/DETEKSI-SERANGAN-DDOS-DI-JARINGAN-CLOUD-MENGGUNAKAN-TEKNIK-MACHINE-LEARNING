# %% [markdown]
# # Import Library Mann Whitney

# %%
import pandas as pd
from scipy.stats import mannwhitneyu

# %% [markdown]
# # Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
# Out:
# Mounted at /content/drive

# %% [markdown]
# # RF

# %% [markdown]
# # RF BASELINE VS RF CFS

# %% [markdown]
# Read Dataset

# %%
rf_base = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RF/baseline_rf_results.csv')
rf_cfs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RF/rf_cfs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: RF_Baseline vs RF_CFS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(rf_base[metric], rf_cfs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: RF_Baseline vs RF_CFS ===
#
# Accuracy:
#   U-Statistik = 44.5000
#   p-value     = 0.693707
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Precision:
#   U-Statistik = 44.0000
#   p-value     = 0.584291
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Recall:
#   U-Statistik = 50.0000
#   p-value     = 1.000000
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# F1_Score:
#   U-Statistik = 45.0000
#   p-value     = 0.725885
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Kappa:
#   U-Statistik = 44.0000
#   p-value     = 0.669267
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)

# %% [markdown]
# # RF BASELINE VS RF RS

# %% [markdown]
# Read Dataset

# %%
rf_base = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RF/baseline_rf_results.csv')
rf_rs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RF/rf_rs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: RF_Baseline vs RF_RS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(rf_base[metric], rf_rs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: RF_Baseline vs RF_RS ===
#
# Accuracy:
#   U-Statistik = 38.5000
#   p-value     = 0.387802
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Precision:
#   U-Statistik = 39.0000
#   p-value     = 0.255852
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Recall:
#   U-Statistik = 48.5000
#   p-value     = 0.934610
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# F1_Score:
#   U-Statistik = 39.5000
#   p-value     = 0.435174
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Kappa:
#   U-Statistik = 37.0000
#   p-value     = 0.332603
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)

# %% [markdown]
# # RF CFS VS RF RS (Feature Selection)

# %% [markdown]
# Read Dataset

# %%
rf_cfs = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RF/rf_cfs_results.csv')
rf_rs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RF/rf_rs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05  # nilai alpha 5%

print("=== Uji Mann-Whitney: RF_CFS vs RF_RS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(rf_cfs[metric], rf_rs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: RF_CFS vs RF_RS ===
#
# Accuracy:
#   U-Statistik = 46.0000
#   p-value     = 0.781309
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Precision:
#   U-Statistik = 44.5000
#   p-value     = 0.542802
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Recall:
#   U-Statistik = 48.5000
#   p-value     = 0.934610
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# F1_Score:
#   U-Statistik = 46.5000
#   p-value     = 0.812826
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Kappa:
#   U-Statistik = 45.0000
#   p-value     = 0.724296
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)

# %% [markdown]
# # KNN

# %% [markdown]
# # KNN BASELINE VS KNN CFS

# %% [markdown]
# Read Dataset

# %%
knn_base = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/KNN/baseline_knn_results.csv')
knn_cfs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/KNN/knn_cfs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: KNN_Baseline vs KNN_CFS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(knn_base[metric], knn_cfs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: KNN_Baseline vs KNN_CFS ===
#
# Accuracy:
#   U-Statistik = 26.5000
#   p-value     = 0.080718
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Precision:
#   U-Statistik = 33.5000
#   p-value     = 0.224725
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Recall:
#   U-Statistik = 28.5000
#   p-value     = 0.108076
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# F1_Score:
#   U-Statistik = 26.0000
#   p-value     = 0.074892
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Kappa:
#   U-Statistik = 26.5000
#   p-value     = 0.081754
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)

# %% [markdown]
# # KNN BASELINE VS KNN RS

# %% [markdown]
# Read Dataset

# %%
knn_base = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/KNN/baseline_knn_results.csv')
knn_rs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/KNN/knn_rs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: KNN_Baseline vs KNN_RS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(knn_base[metric], knn_rs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: KNN_Baseline vs KNN_RS ===
#
# Accuracy:
#   U-Statistik = 35.0000
#   p-value     = 0.270500
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Precision:
#   U-Statistik = 43.5000
#   p-value     = 0.649409
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Recall:
#   U-Statistik = 34.0000
#   p-value     = 0.239013
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# F1_Score:
#   U-Statistik = 35.0000
#   p-value     = 0.272675
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Kappa:
#   U-Statistik = 35.0000
#   p-value     = 0.273036
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)

# %% [markdown]
# # KNN CFS VS KNN RS

# %% [markdown]
# Read Dataset

# %%
knn_cfs = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/KNN/knn_cfs_results.csv')
knn_rs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/KNN/knn_rs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: KNN_CFS vs KNN_RS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(knn_cfs[metric], knn_rs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: KNN_CFS vs KNN_RS ===
#
# Accuracy:
#   U-Statistik = 60.0000
#   p-value     = 0.465545
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Precision:
#   U-Statistik = 51.0000
#   p-value     = 0.969679
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Recall:
#   U-Statistik = 56.0000
#   p-value     = 0.675039
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# F1_Score:
#   U-Statistik = 61.0000
#   p-value     = 0.426135
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Kappa:
#   U-Statistik = 60.0000
#   p-value     = 0.472342
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)

# %% [markdown]
# # SVM

# %% [markdown]
# # SVM BASELINE VS SVM CFS

# %% [markdown]
# Read Dataset

# %%
svm_base = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SVM/baseline_svm_results.csv')
svm_cfs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SVM/svm_cfs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: SVM_Baseline vs SVM_CFS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(svm_base[metric], svm_cfs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: SVM_Baseline vs SVM_CFS ===
#
# Accuracy:
#   U-Statistik = 38.0000
#   p-value     = 0.383598
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Precision:
#   U-Statistik = 57.0000
#   p-value     = 0.622653
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Recall:
#   U-Statistik = 19.5000
#   p-value     = 0.022311
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# F1_Score:
#   U-Statistik = 37.0000
#   p-value     = 0.344704
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Kappa:
#   U-Statistik = 40.0000
#   p-value     = 0.472676
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)

# %% [markdown]
# # SVM BASELINE VS SVM RS

# %% [markdown]
# Read Dataset

# %%
svm_base = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SVM/baseline_svm_results.csv')
svm_rs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SVM/svm_rs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: SVM_Baseline vs SVM_RS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(svm_base[metric], svm_rs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: SVM_Baseline vs SVM_RS ===
#
# Accuracy:
#   U-Statistik = 56.0000
#   p-value     = 0.675855
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Precision:
#   U-Statistik = 54.0000
#   p-value     = 0.790411
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Recall:
#   U-Statistik = 58.5000
#   p-value     = 0.542298
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# F1_Score:
#   U-Statistik = 54.0000
#   p-value     = 0.790875
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Kappa:
#   U-Statistik = 56.5000
#   p-value     = 0.649902
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)

# %% [markdown]
# # SVM CFS VS SVM RS

# %% [markdown]
# Read Dataset

# %%
svm_cfs = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SVM/svm_cfs_results.csv')
svm_rs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SVM/svm_rs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: SVM_CFS vs SVM_RS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(svm_cfs[metric], svm_rs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: SVM_CFS vs SVM_RS ===
#
# Accuracy:
#   U-Statistik = 63.5000
#   p-value     = 0.323191
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Precision:
#   U-Statistik = 48.0000
#   p-value     = 0.909314
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Recall:
#   U-Statistik = 92.0000
#   p-value     = 0.001521
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# F1_Score:
#   U-Statistik = 69.0000
#   p-value     = 0.161341
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Kappa:
#   U-Statistik = 60.0000
#   p-value     = 0.472509
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
