# %% [markdown]
# # Import Library Mann Whitney

# %%
import pandas as pd
from scipy.stats import mannwhitneyu

# %% [markdown]
# # Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1. RF CFS vs KNN CFS
# 2. RF CFS vs KNN RS
# 3. RF CFS vs SVM CFS
# 4. RF CFS vs SVM RS
# 5. RF RS vs KNN CFS
# 6. RF RS vs KNN RS
# 7. RF RS vs SVM CFS
# 8. RF RS vs SVM RS
# 9. KNN CFS vs SVM CFS
# 10. KNN CFS vs SVM RS
# 11. KNN RS vs SVM CFS
# 12. KNN RS vs SVM RS

# %% [markdown]
# # 1. RF CFS VS KNN CFS

# %% [markdown]
# Read Dataset

# %%
rf_cfs = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RF/rf_cfs_results.csv')
knn_cfs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/KNN/knn_cfs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: RF_CFS vs KNN_CFS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(rf_cfs[metric], knn_cfs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: RF_CFS vs KNN_CFS ===
#
# Accuracy:
#   U-Statistik = 100.0000
#   p-value     = 0.000165
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Precision:
#   U-Statistik = 93.5000
#   p-value     = 0.000645
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Recall:
#   U-Statistik = 95.0000
#   p-value     = 0.000618
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# F1_Score:
#   U-Statistik = 100.0000
#   p-value     = 0.000170
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Kappa:
#   U-Statistik = 100.0000
#   p-value     = 0.000172
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)

# %% [markdown]
# # 2. RF CFS VS KNN RS

# %% [markdown]
# Read Dataset

# %%
rf_cfs = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RF/rf_cfs_results.csv')
knn_rs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/KNN/knn_rs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: RF_CFS vs KNN_RS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(rf_cfs[metric], knn_rs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: RF_CFS vs KNN_RS ===
#
# Accuracy:
#   U-Statistik = 93.0000
#   p-value     = 0.001146
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Precision:
#   U-Statistik = 81.5000
#   p-value     = 0.010280
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Recall:
#   U-Statistik = 94.0000
#   p-value     = 0.000869
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# F1_Score:
#   U-Statistik = 94.0000
#   p-value     = 0.000943
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Kappa:
#   U-Statistik = 92.5000
#   p-value     = 0.001426
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)

# %% [markdown]
# # 3. RF CFS VS SVM CFS

# %% [markdown]
# Read Dataset

# %%
rf_cfs = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RF/rf_cfs_results.csv')
svm_cfs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SVM/svm_cfs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: RF_CFS vs SVM_CFS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(rf_cfs[metric], svm_cfs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: RF_CFS vs SVM_CFS ===
#
# Accuracy:
#   U-Statistik = 100.0000
#   p-value     = 0.000167
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Precision:
#   U-Statistik = 100.0000
#   p-value     = 0.000109
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Recall:
#   U-Statistik = 84.5000
#   p-value     = 0.008534
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# F1_Score:
#   U-Statistik = 100.0000
#   p-value     = 0.000171
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Kappa:
#   U-Statistik = 100.0000
#   p-value     = 0.000172
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)

# %% [markdown]
# # 4. RF CFS VS SVM RS

# %% [markdown]
# Read Dataset

# %%
rf_cfs = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RF/rf_cfs_results.csv')
svm_rs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SVM/svm_rs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: RF_CFS vs SVM_RS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(rf_cfs[metric], svm_rs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: RF_CFS vs SVM_RS ===
#
# Accuracy:
#   U-Statistik = 100.0000
#   p-value     = 0.000166
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Precision:
#   U-Statistik = 100.0000
#   p-value     = 0.000104
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Recall:
#   U-Statistik = 100.0000
#   p-value     = 0.000157
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# F1_Score:
#   U-Statistik = 100.0000
#   p-value     = 0.000167
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Kappa:
#   U-Statistik = 100.0000
#   p-value     = 0.000171
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)

# %% [markdown]
# # 5. RF RS vs KNN CFS

# %% [markdown]
# Read Dataset

# %%
rf_rs = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RF/rf_rs_results.csv')
knn_cfs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/KNN/knn_cfs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: RF_RS vs KNN_CFS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(rf_rs[metric], knn_cfs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: RF_RS vs KNN_CFS ===
#
# Accuracy:
#   U-Statistik = 100.0000
#   p-value     = 0.000165
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Precision:
#   U-Statistik = 94.5000
#   p-value     = 0.000375
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Recall:
#   U-Statistik = 99.5000
#   p-value     = 0.000169
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# F1_Score:
#   U-Statistik = 100.0000
#   p-value     = 0.000162
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Kappa:
#   U-Statistik = 100.0000
#   p-value     = 0.000171
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)

# %% [markdown]
# # 6. RF RS vs KNN RS

# %% [markdown]
# Read Dataset

# %%
rf_rs = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RF/rf_rs_results.csv')
knn_rs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/KNN/knn_rs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: RF_RS vs KNN_RS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(rf_rs[metric], knn_rs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: RF_RS vs KNN_RS ===
#
# Accuracy:
#   U-Statistik = 95.0000
#   p-value     = 0.000661
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Precision:
#   U-Statistik = 83.5000
#   p-value     = 0.004869
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Recall:
#   U-Statistik = 94.0000
#   p-value     = 0.000776
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# F1_Score:
#   U-Statistik = 96.5000
#   p-value     = 0.000432
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Kappa:
#   U-Statistik = 95.0000
#   p-value     = 0.000717
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)

# %% [markdown]
# # 7. RF RS vs SVM CFS

# %% [markdown]
# Read Dataset

# %%
rf_rs = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RF/rf_rs_results.csv')
svm_cfs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SVM/svm_cfs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: RF_RS vs SVM_CFS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(rf_rs[metric], svm_cfs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: RF_RS vs SVM_CFS ===
#
# Accuracy:
#   U-Statistik = 100.0000
#   p-value     = 0.000167
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Precision:
#   U-Statistik = 100.0000
#   p-value     = 0.000086
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Recall:
#   U-Statistik = 89.0000
#   p-value     = 0.002888
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# F1_Score:
#   U-Statistik = 100.0000
#   p-value     = 0.000163
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Kappa:
#   U-Statistik = 100.0000
#   p-value     = 0.000171
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)

# %% [markdown]
# # 8. RF RS vs SVM RS

# %% [markdown]
# Read Dataset

# %%
rf_rs = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RF/rf_rs_results.csv')
svm_rs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SVM/svm_rs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: RF_RS vs SVM_RS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(rf_rs[metric], svm_rs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: RF_RS vs SVM_RS ===
#
# Accuracy:
#   U-Statistik = 100.0000
#   p-value     = 0.000166
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Precision:
#   U-Statistik = 100.0000
#   p-value     = 0.000082
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Recall:
#   U-Statistik = 100.0000
#   p-value     = 0.000149
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# F1_Score:
#   U-Statistik = 100.0000
#   p-value     = 0.000159
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Kappa:
#   U-Statistik = 100.0000
#   p-value     = 0.000170
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)

# %% [markdown]
# # 9. KNN CFS vs SVM CFS

# %% [markdown]
# Read Dataset

# %%
knn_cfs = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/KNN/knn_cfs_results.csv')
svm_cfs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SVM/svm_cfs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: KNN_CFS vs SVM_CFS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(knn_cfs[metric], svm_cfs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: KNN_CFS vs SVM_CFS ===
#
# Accuracy:
#   U-Statistik = 87.0000
#   p-value     = 0.005613
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Precision:
#   U-Statistik = 97.5000
#   p-value     = 0.000371
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Recall:
#   U-Statistik = 30.5000
#   p-value     = 0.141929
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# F1_Score:
#   U-Statistik = 84.5000
#   p-value     = 0.010109
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Kappa:
#   U-Statistik = 88.5000
#   p-value     = 0.004058
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)

# %% [markdown]
# # 10. KNN CFS vs SVM RS

# %% [markdown]
# Read Dataset

# %%
knn_cfs = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/KNN/knn_cfs_results.csv')
svm_rs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SVM/svm_rs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: KNN_CFS vs SVM_RS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(knn_cfs[metric], svm_rs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: KNN_CFS vs SVM_RS ===
#
# Accuracy:
#   U-Statistik = 100.0000
#   p-value     = 0.000178
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Precision:
#   U-Statistik = 97.0000
#   p-value     = 0.000414
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Recall:
#   U-Statistik = 75.5000
#   p-value     = 0.054903
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# F1_Score:
#   U-Statistik = 100.0000
#   p-value     = 0.000178
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Kappa:
#   U-Statistik = 100.0000
#   p-value     = 0.000182
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)

# %% [markdown]
# # 11. KNN RS vs SVM CFS

# %% [markdown]
# Read Dataset

# %%
knn_rs = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/KNN/knn_rs_results.csv')
svm_cfs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SVM/svm_cfs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: KNN_RS vs SVM_CFS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(knn_rs[metric], svm_cfs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: KNN_RS vs SVM_CFS ===
#
# Accuracy:
#   U-Statistik = 78.5000
#   p-value     = 0.032816
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Precision:
#   U-Statistik = 94.5000
#   p-value     = 0.000853
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Recall:
#   U-Statistik = 26.5000
#   p-value     = 0.080028
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# F1_Score:
#   U-Statistik = 75.5000
#   p-value     = 0.058592
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# Kappa:
#   U-Statistik = 80.0000
#   p-value     = 0.025748
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)

# %% [markdown]
# # 12. KNN RS vs SVM RS

# %% [markdown]
# Read Dataset

# %%
knn_rs = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/KNN/knn_rs_results.csv')
svm_rs  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SVM/svm_rs_results.csv')

# %% [markdown]
# Mulai Uji

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1_Score', 'Kappa']
alpha = 0.05

print("=== Uji Mann-Whitney: KNN_RS vs SVM_RS ===\n")

for metric in metrics:
    stat, p = mannwhitneyu(knn_rs[metric], svm_rs[metric], alternative='two-sided')
    print(f"{metric}:")
    print(f"  U-Statistik = {stat:.4f}")
    print(f"  p-value     = {p:.6f}")
    if p < alpha:
        print("  👉 Perbedaan SIGNIFIKAN (p < 0.05)\n")
    else:
        print("  👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)\n")
# Out:
# === Uji Mann-Whitney: KNN_RS vs SVM_RS ===
#
# Accuracy:
#   U-Statistik = 96.0000
#   p-value     = 0.000550
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Precision:
#   U-Statistik = 93.0000
#   p-value     = 0.001239
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Recall:
#   U-Statistik = 67.0000
#   p-value     = 0.207794
#   👉 Perbedaan TIDAK SIGNIFIKAN (p ≥ 0.05)
#
# F1_Score:
#   U-Statistik = 96.0000
#   p-value     = 0.000569
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
#
# Kappa:
#   U-Statistik = 96.0000
#   p-value     = 0.000580
#   👉 Perbedaan SIGNIFIKAN (p < 0.05)
